# %%
import tensorflow as tf
import os
import pandas as pd
import numpy as np

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True)
csv_path, _ = os.path.splitext(zip_path)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip
# 13568290/13568290 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
df = pd.read_csv(csv_path)
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 0        93.30          3.33          3.11          0.22       1.94
# 1        93.40          3.23          3.02          0.21       1.89
# 2        93.90          3.21          3.01          0.20       1.88
# 3        94.20          3.26          3.07          0.19       1.92
# 4        94.10          3.27          3.08          0.19       1.92
# ...        ...           ...           ...           ...        ...
# 420546   73.10          4.52          3.30          1.22       2.06
# 420547   69.71          4.77          3.32          1.44       2.07
# 420548   67.91          4.84          3.28          1.55       2.05
# 420549   71.80          4.46          3.20          1.26       1.99
# 420550   75.70          4.27          3.23          1.04       2.01
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 0                  3.12       1307.75      1.03           1.75     152.3
# 1                  3.03       1309.80      0.72           1.50     136.1
# 2                  3.02       1310.24      0.19           0.63     171.6
# 3                  3.08       1309.19      0.34           0.50     198.0
# 4                  3.09       1309.00      0.32           0.63     214.3
# ...                 ...           ...       ...            ...       ...
# 420546             3.30       1292.98      0.67           1.52     240.0
# 420547             3.32       1289.44      1.14           1.92     234.3
# 420548             3.28       1288.39      1.08           2.00     215.2
# 420549             3.20       1293.56      1.49           2.16     225.8
# 420550             3.23       1296.38      1.23           1.96     184.9
#
# [420551 rows x 15 columns]

# %%
df = df[5::6]
df
# Out:
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 5       01.01.2009 01:00:00    996.50     -8.05    265.38        -8.78
# 11      01.01.2009 02:00:00    996.62     -8.88    264.54        -9.77
# 17      01.01.2009 03:00:00    996.84     -8.81    264.59        -9.66
# 23      01.01.2009 04:00:00    996.99     -9.05    264.34       -10.02
# 29      01.01.2009 05:00:00    997.46     -9.63    263.72       -10.65
# ...                     ...       ...       ...       ...          ...
# 420521  31.12.2016 19:10:00   1002.18     -0.98    272.01        -5.36
# 420527  31.12.2016 20:10:00   1001.40     -1.40    271.66        -6.84
# 420533  31.12.2016 21:10:00   1001.19     -2.75    270.32        -6.90
# 420539  31.12.2016 22:10:00   1000.65     -2.89    270.22        -7.15
# 420545  31.12.2016 23:10:00   1000.11     -3.93    269.23        -8.09
#
#         rh (%)  VPmax (mbar)  VPact (mbar)  VPdef (mbar)  sh (g/kg)  \
# 5        94.40          3.33          3.14          0.19       1.96
# 11       93.20          3.12          2.90          0.21       1.81
# 17       93.50          3.13          2.93          0.20       1.83
# 23       92.60          3.07          2.85          0.23       1.78
# 29       92.20          2.94          2.71          0.23       1.69
# ...        ...           ...           ...           ...        ...
# 420521   72.00          5.69          4.09          1.59       2.54
# 420527   66.29          5.51          3.65          1.86       2.27
# 420533   72.90          4.99          3.64          1.35       2.26
# 420539   72.30          4.93          3.57          1.37       2.22
# 420545   72.60          4.56          3.31          1.25       2.06
#
#         H2OC (mmol/mol)  rho (g/m**3)  wv (m/s)  max. wv (m/s)  wd (deg)
# 5                  3.15       1307.86      0.21           0.63     192.7
# 11                 2.91       1312.25      0.25           0.63     190.3
# 17                 2.94       1312.18      0.18           0.63     167.2
# 23                 2.85       1313.61      0.10           0.38     240.0
# 29                 2.71       1317.19      0.40           0.88     157.0
# ...                 ...           ...       ...            ...       ...
# 420521             4.08       1280.70      0.87           1.36     190.6
# 420527             3.65       1281.87      1.02           1.92     225.4
# 420533             3.63       1288.02      0.71           1.56     158.7
# 420539             3.57       1288.03      0.35           0.68     216.7
# 420545             3.31       1292.41      0.56           1.00     202.6
#
# [70091 rows x 15 columns]

# %%
df.index = pd.to_datetime(df['Date Time'], format='%d.%m.%Y %H:%M:%S')
df[:26]
# Out:
#                                Date Time  p (mbar)  T (degC)  Tpot (K)  \
# Date Time
# 2009-01-01 01:00:00  01.01.2009 01:00:00    996.50     -8.05    265.38
# 2009-01-01 02:00:00  01.01.2009 02:00:00    996.62     -8.88    264.54
# 2009-01-01 03:00:00  01.01.2009 03:00:00    996.84     -8.81    264.59
# 2009-01-01 04:00:00  01.01.2009 04:00:00    996.99     -9.05    264.34
# 2009-01-01 05:00:00  01.01.2009 05:00:00    997.46     -9.63    263.72
# 2009-01-01 06:00:00  01.01.2009 06:00:00    997.71     -9.67    263.66
# 2009-01-01 07:00:00  01.01.2009 07:00:00    998.33     -9.17    264.12
# 2009-01-01 08:00:00  01.01.2009 08:00:00    999.17     -8.10    265.12
# 2009-01-01 09:00:00  01.01.2009 09:00:00    999.69     -7.66    265.52
# 2009-01-01 10:00:00  01.01.2009 10:00:00   1000.27     -7.04    266.10
# 2009-01-01 11:00:00  01.01.2009 11:00:00   1000.87     -7.41    265.68
# 2009-01-01 12:00:00  01.01.2009 12:00:00   1000.30     -6.87    266.27
# 2009-01-01 13:00:00  01.01.2009 13:00:00   1000.03     -5.89    267.27
# 2009-01-01 14:00:00  01.01.2009 14:00:00    999.81     -5.94    267.24
# 2009-01-01 15:00:00  01.01.2009 15:00:00    999.88     -5.69    267.48
# 2009-01-01 16:00:00  01.01.2009 16:00:00    999.94     -5.40    267.76
# 2009-01-01 17:00:00  01.01.2009 17:00:00   1000.17     -5.37    267.78
# 2009-01-01 18:00:00  01.01.2009 18:00:00   1000.16     -5.25    267.90
# 2009-01-01 19:00:00  01.01.2009 19:00:00   1000.22     -5.11    268.03
# 2009-01-01 20:00:00  01.01.2009 20:00:00   1000.22     -4.90    268.24
# 2009-01-01 21:00:00  01.01.2009 21:00:00   1000.19     -4.80    268.35
# 2009-01-01 22:00:00  01.01.2009 22:00:00   1000.00     -4.50    268.66
# 2009-01-01 23:00:00  01.01.2009 23:00:00    999.77     -4.47    268.71
# 2009-01-02 00:00:00  02.01.2009 00:00:00    999.59     -4.54    268.65
# 2009-01-02 01:00:00  02.01.2009 01:00:00    999.34     -4.44    268.77
# 2009-01-02 02:00:00  02.01.2009 02:00:00    998.93     -4.29    268.95
#
#                      Tdew (degC)  rh (%)  VPmax (mbar)  VPact (mbar)  \
# Date Time
# 2009-01-01 01:00:00        -8.78    94.4          3.33          3.14
# 2009-01-01 02:00:00        -9.77    93.2          3.12          2.90
# 2009-01-01 03:00:00        -9.66    93.5          3.13          2.93
# 2009-01-01 04:00:00       -10.02    92.6          3.07          2.85
# 2009-01-01 05:00:00       -10.65    92.2          2.94          2.71
# 2009-01-01 06:00:00       -10.62    92.7          2.93          2.71
# 2009-01-01 07:00:00       -10.10    92.9          3.04          2.83
# 2009-01-01 08:00:00        -9.05    92.8          3.31          3.07
# 2009-01-01 09:00:00        -8.84    91.2          3.43          3.13
# 2009-01-01 10:00:00        -8.17    91.6          3.60          3.30
# 2009-01-01 11:00:00        -8.66    90.7          3.50          3.17
# 2009-01-01 12:00:00        -8.28    89.6          3.64          3.27
# 2009-01-01 13:00:00        -7.46    88.6          3.93          3.48
# 2009-01-01 14:00:00        -7.43    89.1          3.92          3.49
# 2009-01-01 15:00:00        -7.00    90.4          3.99          3.61
# 2009-01-01 16:00:00        -6.86    89.4          4.08          3.65
# 2009-01-01 17:00:00        -6.82    89.4          4.09          3.66
# 2009-01-01 18:00:00        -6.75    89.1          4.13          3.68
# 2009-01-01 19:00:00        -6.57    89.4          4.17          3.73
# 2009-01-01 20:00:00        -6.38    89.3          4.24          3.79
# 2009-01-01 21:00:00        -6.14    90.2          4.27          3.85
# 2009-01-01 22:00:00        -5.82    90.4          4.37          3.95
# 2009-01-01 23:00:00        -5.84    90.1          4.38          3.95
# 2009-01-02 00:00:00        -5.46    93.2          4.36          4.06
# 2009-01-02 01:00:00        -5.19    94.4          4.39          4.15
# 2009-01-02 02:00:00        -5.04    94.5          4.44          4.20
#
#                      VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# Date Time
# 2009-01-01 01:00:00          0.19       1.96             3.15       1307.86
# 2009-01-01 02:00:00          0.21       1.81             2.91       1312.25
# 2009-01-01 03:00:00          0.20       1.83             2.94       1312.18
# 2009-01-01 04:00:00          0.23       1.78             2.85       1313.61
# 2009-01-01 05:00:00          0.23       1.69             2.71       1317.19
# 2009-01-01 06:00:00          0.21       1.69             2.72       1317.71
# 2009-01-01 07:00:00          0.22       1.76             2.83       1315.98
# 2009-01-01 08:00:00          0.24       1.92             3.08       1311.65
# 2009-01-01 09:00:00          0.30       1.95             3.13       1310.14
# 2009-01-01 10:00:00          0.30       2.05             3.29       1307.76
# 2009-01-01 11:00:00          0.33       1.97             3.17       1310.43
# 2009-01-01 12:00:00          0.38       2.03             3.26       1306.98
# 2009-01-01 13:00:00          0.45       2.17             3.48       1301.73
# 2009-01-01 14:00:00          0.43       2.17             3.49       1301.67
# 2009-01-01 15:00:00          0.38       2.25             3.61       1300.51
# 2009-01-01 16:00:00          0.43       2.27             3.65       1299.17
# 2009-01-01 17:00:00          0.43       2.28             3.66       1299.27
# 2009-01-01 18:00:00          0.45       2.29             3.68       1298.68
# 2009-01-01 19:00:00          0.44       2.32             3.73       1298.07
# 2009-01-01 20:00:00          0.45       2.36             3.78       1297.05
# 2009-01-01 21:00:00          0.42       2.40             3.85       1296.45
# 2009-01-01 22:00:00          0.42       2.46             3.95       1294.72
# 2009-01-01 23:00:00          0.43       2.46             3.95       1294.29
# 2009-01-02 00:00:00          0.30       2.53             4.06       1294.33
# 2009-01-02 01:00:00          0.25       2.58             4.15       1293.47
# 2009-01-02 02:00:00          0.24       2.62             4.20       1292.22
#
#                      wv (m/s)  max. wv (m/s)  wd (deg)
# Date Time
# 2009-01-01 01:00:00      0.21           0.63     192.7
# 2009-01-01 02:00:00      0.25           0.63     190.3
# 2009-01-01 03:00:00      0.18           0.63     167.2
# 2009-01-01 04:00:00      0.10           0.38     240.0
# 2009-01-01 05:00:00      0.40           0.88     157.0
# 2009-01-01 06:00:00      0.05           0.50     146.0
# 2009-01-01 07:00:00      2.08           2.88     348.8
# 2009-01-01 08:00:00      0.72           1.25     213.9
# 2009-01-01 09:00:00      0.34           0.63     202.2
# 2009-01-01 10:00:00      1.45           3.00     292.6
# 2009-01-01 11:00:00      1.91           3.38     269.6
# 2009-01-01 12:00:00      1.84           2.63     184.4
# 2009-01-01 13:00:00      0.57           1.25     187.3
# 2009-01-01 14:00:00      1.25           2.00     144.0
# 2009-01-01 15:00:00      1.17           1.88     134.9
# 2009-01-01 16:00:00      1.40           2.13     145.5
# 2009-01-01 17:00:00      0.85           1.63     142.2
# 2009-01-01 18:00:00      0.55           1.00     183.7
# 2009-01-01 19:00:00      0.41           0.75     176.7
# 2009-01-01 20:00:00      0.68           1.13     195.2
# 2009-01-01 21:00:00      0.44           0.75     206.3
# 2009-01-01 22:00:00      0.33           0.63     175.7
# 2009-01-01 23:00:00      0.65           1.00     219.3
# 2009-01-02 00:00:00      0.41           0.88     155.0
# 2009-01-02 01:00:00      0.28           1.00     148.1
# 2009-01-02 02:00:00      0.49           0.88     209.8

# %%
temp = df['T (degC)']
temp.plot()
# Out:
# <Axes: xlabel='Date Time'>

# %%
# [[[1], [2], [3], [4], [5]]] [6]
# [[[2], [3], [4], [5], [6]]] [7]
# [[[3], [4], [5], [6], [7]]] [8]

def df_to_X_y(df, window_size=5):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [[a] for a in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size]
    y.append(label)
  return np.array(X), np.array(y)

# %%
WINDOW_SIZE = 5
X1, y1 = df_to_X_y(temp, WINDOW_SIZE)
X1.shape, y1.shape
# Out:
# ((70086, 5, 1), (70086,))

# %%
X_train1, y_train1 = X1[:60000], y1[:60000]
X_val1, y_val1 = X1[60000:65000], y1[60000:65000]
X_test1, y_test1 = X1[65000:], y1[65000:]
X_train1.shape, y_train1.shape, X_val1.shape, y_val1.shape, X_test1.shape, y_test1.shape
# Out:
# ((60000, 5, 1), (60000,), (5000, 5, 1), (5000,), (5086, 5, 1), (5086,))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.optimizers import Adam

model1 = Sequential()
model1.add(InputLayer((5, 1)))
model1.add(LSTM(64))
model1.add(Dense(8, 'relu'))
model1.add(Dense(1, 'linear'))

model1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 64)                  │          16,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 17,425 (68.07 KB)
#  Trainable params: 17,425 (68.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp1 = ModelCheckpoint('model1.keras', save_best_only=True)
model1.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model1.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp1])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 82.7333 - root_mean_squared_error: 8.8962 - val_loss: 1.8761 - val_root_mean_squared_error: 1.3697
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 4.8947 - root_mean_squared_error: 2.2005 - val_loss: 0.6870 - val_root_mean_squared_error: 0.8289
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 1.3715 - root_mean_squared_error: 1.1696 - val_loss: 0.5719 - val_root_mean_squared_error: 0.7563
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.8353 - root_mean_squared_error: 0.9138 - val_loss: 0.5265 - val_root_mean_squared_error: 0.7256
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.7147 - root_mean_squared_error: 0.8453 - val_loss: 0.5011 - val_root_mean_squared_error: 0.7079
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.6932 - root_mean_squared_error: 0.8325 - val_loss: 0.5015 - val_root_mean_squared_error: 0.7082
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.6675 - root_mean_squared_error: 0.8170 - val_loss: 0.5014 - val_root_mean_squared_error: 0.7081
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.6591 - root_mean_squared_error: 0.8117 - val_loss: 0.4915 - val_root_mean_squared_error: 0.7010
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 0.6394 - root_mean_squared_error: 0.7995 - val_loss: 0.5133 - val_root_mean_squared_error: 0.7164
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.6413 - root_mean_squared_error: 0.8008 - val_loss: 0.5132 - val_root_mean_squared_error: 0.7163

# %%
from tensorflow.keras.models import load_model
model1 = load_model('model1.keras')

# %%
train_predictions = model1.predict(X_train1).flatten()
train_results = pd.DataFrame(data={'Train Predictions':train_predictions, 'Actuals':y_train1})
train_results
# Out:
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
#        Train Predictions  Actuals
# 0              -9.977921    -9.67
# 1              -9.758720    -9.17
# 2              -8.899365    -8.10
# 3              -7.460496    -7.66
# 4              -7.360250    -7.04
# ...                  ...      ...
# 59995           5.944530     6.07
# 59996           7.227826     9.88
# 59997          12.003830    13.53
# 59998          15.925155    15.43
# 59999          16.107622    15.54
#
# [60000 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
plt.plot(train_results['Train Predictions'][50:100])
plt.plot(train_results['Actuals'][50:100])

# %%
val_predictions = model1.predict(X_val1).flatten()
val_results = pd.DataFrame(data={'Val Predictions':val_predictions, 'Actuals':y_val1})
val_results
# Out:
# 157/157 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
#       Val Predictions  Actuals
# 0           15.384962    14.02
# 1           13.262145    13.67
# 2           13.073772    12.27
# 3           11.565653    11.19
# 4           10.464665    10.85
# ...               ...      ...
# 4995        17.259899    18.27
# 4996        17.314373    17.85
# 4997        17.223703    16.65
# 4998        15.878958    15.85
# 4999        15.094016    15.09
#
# [5000 rows x 2 columns]

# %%
plt.plot(val_results['Val Predictions'][:100])
plt.plot(val_results['Actuals'][:100])

# %%
test_predictions = model1.predict(X_test1).flatten()
test_results = pd.DataFrame(data={'Test Predictions':test_predictions, 'Actuals':y_test1})
test_results
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#       Test Predictions  Actuals
# 0            14.448127    13.99
# 1            13.306373    13.46
# 2            12.931229    12.93
# 3            12.543127    12.43
# 4            12.095515    12.17
# ...                ...      ...
# 5081         -0.923884    -0.98
# 5082         -1.509113    -1.40
# 5083         -1.753073    -2.75
# 5084         -3.239504    -2.89
# 5085         -3.227638    -3.93
#
# [5086 rows x 2 columns]

# %%
plt.plot(test_results['Test Predictions'][:100])
plt.plot(test_results['Actuals'][:100])

# %%
# Part 2

# %%
from sklearn.metrics import mean_squared_error as mse

def plot_predictions1(model, X, y, start=0, end=100):
  predictions = model.predict(X).flatten()
  df = pd.DataFrame(data={'Predictions':predictions, 'Actuals':y})
  plt.plot(df['Predictions'][start:end])
  plt.plot(df['Actuals'][start:end])
  return df, mse(y, predictions)

# %%
plot_predictions1(model1, X_test1, y_test1)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# (      Predictions  Actuals
#  0       14.448127    13.99
#  1       13.306373    13.46
#  2       12.931229    12.93
#  3       12.543127    12.43
#  4       12.095515    12.17
#  ...           ...      ...
#  5081    -0.923884    -0.98
#  5082    -1.509113    -1.40
#  5083    -1.753073    -2.75
#  5084    -3.239504    -2.89
#  5085    -3.227638    -3.93
#
#  [5086 rows x 2 columns],
#  0.634892592178054)

# %%
model2 = Sequential()
model2.add(InputLayer((5, 1)))
model2.add(Conv1D(64, kernel_size=2))
model2.add(Flatten())
model2.add(Dense(8, 'relu'))
model2.add(Dense(1, 'linear'))

model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                      │ (None, 4, 64)               │             192 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │           2,056 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,257 (8.82 KB)
#  Trainable params: 2,257 (8.82 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp2 = ModelCheckpoint('model2.keras', save_best_only=True)
model2.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model2.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp2])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 26.3613 - root_mean_squared_error: 4.7050 - val_loss: 1.3375 - val_root_mean_squared_error: 1.1565
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 1.4962 - root_mean_squared_error: 1.2213 - val_loss: 0.7641 - val_root_mean_squared_error: 0.8742
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.8983 - root_mean_squared_error: 0.9474 - val_loss: 0.5575 - val_root_mean_squared_error: 0.7466
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.7325 - root_mean_squared_error: 0.8558 - val_loss: 0.5375 - val_root_mean_squared_error: 0.7331
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.6770 - root_mean_squared_error: 0.8226 - val_loss: 0.5231 - val_root_mean_squared_error: 0.7233
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - loss: 0.6755 - root_mean_squared_error: 0.8218 - val_loss: 0.4990 - val_root_mean_squared_error: 0.7064
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.6729 - root_mean_squared_error: 0.8199 - val_loss: 0.5137 - val_root_mean_squared_error: 0.7167
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.6816 - root_mean_squared_error: 0.8254 - val_loss: 0.4897 - val_root_mean_squared_error: 0.6998
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.6708 - root_mean_squared_error: 0.8190 - val_loss: 0.4887 - val_root_mean_squared_error: 0.6991
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 1ms/step - loss: 0.6521 - root_mean_squared_error: 0.8074 - val_loss: 0.5005 - val_root_mean_squared_error: 0.7075

# %%
model3 = Sequential()
model3.add(InputLayer((5, 1)))
model3.add(GRU(64))
model3.add(Dense(8, 'relu'))
model3.add(Dense(1, 'linear'))
model3.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ gru (GRU)                            │ (None, 64)                  │          12,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,393 (52.32 KB)
#  Trainable params: 13,393 (52.32 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp3 = ModelCheckpoint('model3.keras', save_best_only=True)
model3.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model3.fit(X_train1, y_train1, validation_data=(X_val1, y_val1), epochs=10, callbacks=[cp3])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 139.7589 - root_mean_squared_error: 11.7390 - val_loss: 2.1314 - val_root_mean_squared_error: 1.4599
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 5.6141 - root_mean_squared_error: 2.3518 - val_loss: 0.6821 - val_root_mean_squared_error: 0.8259
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 1.2928 - root_mean_squared_error: 1.1355 - val_loss: 0.5382 - val_root_mean_squared_error: 0.7336
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - loss: 0.8017 - root_mean_squared_error: 0.8952 - val_loss: 0.5083 - val_root_mean_squared_error: 0.7130
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.6871 - root_mean_squared_error: 0.8288 - val_loss: 0.4974 - val_root_mean_squared_error: 0.7052
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.6595 - root_mean_squared_error: 0.8120 - val_loss: 0.5037 - val_root_mean_squared_error: 0.7097
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.6641 - root_mean_squared_error: 0.8148 - val_loss: 0.4938 - val_root_mean_squared_error: 0.7027
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.6327 - root_mean_squared_error: 0.7953 - val_loss: 0.4942 - val_root_mean_squared_error: 0.7030
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.6443 - root_mean_squared_error: 0.8027 - val_loss: 0.5018 - val_root_mean_squared_error: 0.7084
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - loss: 0.6389 - root_mean_squared_error: 0.7991 - val_loss: 0.4913 - val_root_mean_squared_error: 0.7009

# %%
temp_df = pd.DataFrame({'Temperature':temp})
temp_df['Seconds'] = temp_df.index.map(pd.Timestamp.timestamp)
temp_df
# Out:
#                      Temperature       Seconds
# Date Time
# 2009-01-01 01:00:00        -8.05  1.230772e+09
# 2009-01-01 02:00:00        -8.88  1.230775e+09
# 2009-01-01 03:00:00        -8.81  1.230779e+09
# 2009-01-01 04:00:00        -9.05  1.230782e+09
# 2009-01-01 05:00:00        -9.63  1.230786e+09
# ...                          ...           ...
# 2016-12-31 19:10:00        -0.98  1.483211e+09
# 2016-12-31 20:10:00        -1.40  1.483215e+09
# 2016-12-31 21:10:00        -2.75  1.483219e+09
# 2016-12-31 22:10:00        -2.89  1.483222e+09
# 2016-12-31 23:10:00        -3.93  1.483226e+09
#
# [70091 rows x 2 columns]

# %%
day = 60*60*24
year = 365.2425*day

temp_df['Day sin'] = np.sin(temp_df['Seconds'] * (2* np.pi / day))
temp_df['Day cos'] = np.cos(temp_df['Seconds'] * (2 * np.pi / day))
temp_df['Year sin'] = np.sin(temp_df['Seconds'] * (2 * np.pi / year))
temp_df['Year cos'] = np.cos(temp_df['Seconds'] * (2 * np.pi / year))
temp_df.head()
# Out:
#                      Temperature       Seconds   Day sin   Day cos  Year sin  \
# Date Time
# 2009-01-01 01:00:00        -8.05  1.230772e+09  0.258819  0.965926  0.010049
# 2009-01-01 02:00:00        -8.88  1.230775e+09  0.500000  0.866025  0.010766
# 2009-01-01 03:00:00        -8.81  1.230779e+09  0.707107  0.707107  0.011483
# 2009-01-01 04:00:00        -9.05  1.230782e+09  0.866025  0.500000  0.012199
# 2009-01-01 05:00:00        -9.63  1.230786e+09  0.965926  0.258819  0.012916
#
#                      Year cos
# Date Time
# 2009-01-01 01:00:00  0.999950
# 2009-01-01 02:00:00  0.999942
# 2009-01-01 03:00:00  0.999934
# 2009-01-01 04:00:00  0.999926
# 2009-01-01 05:00:00  0.999917

# %%
temp_df = temp_df.drop('Seconds', axis=1)
temp_df.head()
# Out:
#                      Temperature   Day sin   Day cos  Year sin  Year cos
# Date Time
# 2009-01-01 01:00:00        -8.05  0.258819  0.965926  0.010049  0.999950
# 2009-01-01 02:00:00        -8.88  0.500000  0.866025  0.010766  0.999942
# 2009-01-01 03:00:00        -8.81  0.707107  0.707107  0.011483  0.999934
# 2009-01-01 04:00:00        -9.05  0.866025  0.500000  0.012199  0.999926
# 2009-01-01 05:00:00        -9.63  0.965926  0.258819  0.012916  0.999917

# %%
def df_to_X_y2(df, window_size=6):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    label = df_as_np[i+window_size][0]
    y.append(label)
  return np.array(X), np.array(y)

# %%
X2, y2 = df_to_X_y2(temp_df)
X2.shape, y2.shape
# Out:
# ((70085, 6, 5), (70085,))

# %%
X2_train, y2_train = X2[:60000], y2[:60000]
X2_val, y2_val = X2[60000:65000], y2[60000:65000]
X2_test, y2_test = X2[65000:], y2[65000:]
X2_train.shape, y2_train.shape, X2_val.shape, y2_val.shape, X2_test.shape, y2_test.shape
# Out:
# ((60000, 6, 5), (60000,), (5000, 6, 5), (5000,), (5085, 6, 5), (5085,))

# %%
#standardization
temp_training_mean = np.mean(X2_train[:, :, 0])
temp_training_std = np.std(X2_train[:, :, 0])

def preprocess(X):
  X[:, :, 0] = (X[:, :, 0] - temp_training_mean) / temp_training_std
  return X

# %%
preprocess(X2_train)
preprocess(X2_val)
preprocess(X2_test)
# Out:
# array([[[ 1.04009706e+00, -9.65925826e-01,  2.58819045e-01,
#           5.22877889e-01, -8.52407598e-01],
#         [ 9.90732794e-01, -8.66025404e-01,  5.00000000e-01,
#           5.22266764e-01, -8.52782169e-01],
#         [ 8.49692028e-01, -7.07106781e-01,  7.07106781e-01,
#           5.21655371e-01, -8.53156301e-01],
#         [ 7.55664851e-01, -5.00000000e-01,  8.66025404e-01,
#           5.21043709e-01, -8.53529995e-01],
#         [ 6.66339032e-01, -2.58819045e-01,  9.65925826e-01,
#           5.20431780e-01, -8.53903251e-01],
#         [ 5.37051663e-01, -7.16474371e-12,  1.00000000e+00,
#           5.19819584e-01, -8.54276068e-01]],
#
#        [[ 9.90732794e-01, -8.66025404e-01,  5.00000000e-01,
#           5.22266764e-01, -8.52782169e-01],
#         [ 8.49692028e-01, -7.07106781e-01,  7.07106781e-01,
#           5.21655371e-01, -8.53156301e-01],
#         [ 7.55664851e-01, -5.00000000e-01,  8.66025404e-01,
#           5.21043709e-01, -8.53529995e-01],
#         [ 6.66339032e-01, -2.58819045e-01,  9.65925826e-01,
#           5.20431780e-01, -8.53903251e-01],
#         [ 5.37051663e-01, -7.16474371e-12,  1.00000000e+00,
#           5.19819584e-01, -8.54276068e-01],
#         [ 4.74758658e-01,  2.58819045e-01,  9.65925826e-01,
#           5.19207120e-01, -8.54648446e-01]],
#
#        [[ 8.49692028e-01, -7.07106781e-01,  7.07106781e-01,
#           5.21655371e-01, -8.53156301e-01],
#         [ 7.55664851e-01, -5.00000000e-01,  8.66025404e-01,
#           5.21043709e-01, -8.53529995e-01],
#         [ 6.66339032e-01, -2.58819045e-01,  9.65925826e-01,
#           5.20431780e-01, -8.53903251e-01],
#         [ 5.37051663e-01, -7.16474371e-12,  1.00000000e+00,
#           5.19819584e-01, -8.54276068e-01],
#         [ 4.74758658e-01,  2.58819045e-01,  9.65925826e-01,
#           5.19207120e-01, -8.54648446e-01],
#         [ 4.12465653e-01,  5.00000000e-01,  8.66025404e-01,
#           5.18594390e-01, -8.55020385e-01]],
#
#        ...,
#
#        [[-5.23104762e-01, -7.37277337e-01, -6.75590208e-01,
#           4.03308458e-03,  9.99991867e-01],
#         [-8.20465711e-01, -8.87010833e-01, -4.61748613e-01,
#           4.74986003e-03,  9.99988719e-01],
#         [-9.55629779e-01, -9.76296007e-01, -2.16439614e-01,
#           5.46663304e-03,  9.99985058e-01],
#         [-1.15661287e+00, -9.99048222e-01,  4.36193874e-02,
#           6.18340325e-03,  9.99980883e-01],
#         [-1.22243189e+00, -9.53716951e-01,  3.00705799e-01,
#           6.90017027e-03,  9.99976194e-01],
#         [-1.27179616e+00, -8.43391446e-01,  5.37299608e-01,
#           7.61693375e-03,  9.99970991e-01]],
#
#        [[-8.20465711e-01, -8.87010833e-01, -4.61748613e-01,
#           4.74986003e-03,  9.99988719e-01],
#         [-9.55629779e-01, -9.76296007e-01, -2.16439614e-01,
#           5.46663304e-03,  9.99985058e-01],
#         [-1.15661287e+00, -9.99048222e-01,  4.36193874e-02,
#           6.18340325e-03,  9.99980883e-01],
#         [-1.22243189e+00, -9.53716951e-01,  3.00705799e-01,
#           6.90017027e-03,  9.99976194e-01],
#         [-1.27179616e+00, -8.43391446e-01,  5.37299608e-01,
#           7.61693375e-03,  9.99970991e-01],
#         [-1.43046702e+00, -6.75590208e-01,  7.37277337e-01,
#           8.33369332e-03,  9.99965274e-01]],
#
#        [[-9.55629779e-01, -9.76296007e-01, -2.16439614e-01,
#           5.46663304e-03,  9.99985058e-01],
#         [-1.15661287e+00, -9.99048222e-01,  4.36193874e-02,
#           6.18340325e-03,  9.99980883e-01],
#         [-1.22243189e+00, -9.53716951e-01,  3.00705799e-01,
#           6.90017027e-03,  9.99976194e-01],
#         [-1.27179616e+00, -8.43391446e-01,  5.37299608e-01,
#           7.61693375e-03,  9.99970991e-01],
#         [-1.43046702e+00, -6.75590208e-01,  7.37277337e-01,
#           8.33369332e-03,  9.99965274e-01],
#         [-1.44692178e+00, -4.61748613e-01,  8.87010833e-01,
#           9.05044860e-03,  9.99959044e-01]]])

# %%
model4 = Sequential()
model4.add(InputLayer((6, 5)))
model4.add(LSTM(64))
model4.add(Dense(8, 'relu'))
model4.add(Dense(1, 'linear'))

model4.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          17,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,449 (72.07 KB)
#  Trainable params: 18,449 (72.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp4 = ModelCheckpoint('model4.keras', save_best_only=True)
model4.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model4.fit(X2_train, y2_train, validation_data=(X2_val, y2_val), epochs=10, callbacks=[cp4])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 81.9383 - root_mean_squared_error: 8.8070 - val_loss: 4.7350 - val_root_mean_squared_error: 2.1760
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 6.9265 - root_mean_squared_error: 2.6275 - val_loss: 1.8682 - val_root_mean_squared_error: 1.3668
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - loss: 2.3198 - root_mean_squared_error: 1.5206 - val_loss: 1.0057 - val_root_mean_squared_error: 1.0028
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 1.2456 - root_mean_squared_error: 1.1154 - val_loss: 0.7247 - val_root_mean_squared_error: 0.8513
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.8915 - root_mean_squared_error: 0.9438 - val_loss: 0.5738 - val_root_mean_squared_error: 0.7575
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.6860 - root_mean_squared_error: 0.8282 - val_loss: 0.4742 - val_root_mean_squared_error: 0.6886
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.5998 - root_mean_squared_error: 0.7744 - val_loss: 0.4387 - val_root_mean_squared_error: 0.6623
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.5545 - root_mean_squared_error: 0.7446 - val_loss: 0.4244 - val_root_mean_squared_error: 0.6515
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.5495 - root_mean_squared_error: 0.7411 - val_loss: 0.4276 - val_root_mean_squared_error: 0.6539
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.5292 - root_mean_squared_error: 0.7274 - val_loss: 0.4201 - val_root_mean_squared_error: 0.6481

# %%
plot_predictions1(model4, X2_test, y2_test)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# (      Predictions  Actuals
#  0       13.472981    13.46
#  1       13.076930    12.93
#  2       12.689979    12.43
#  3       12.379907    12.17
#  4       12.455657    11.55
#  ...           ...      ...
#  5080    -1.044714    -0.98
#  5081    -1.441531    -1.40
#  5082    -1.590695    -2.75
#  5083    -2.815350    -2.89
#  5084    -2.922841    -3.93
#
#  [5085 rows x 2 columns],
#  0.5014999424204614)

# %%
p_temp_df = pd.concat([df['p (mbar)'], temp_df], axis=1)
p_temp_df.head()
# Out:
#                      p (mbar)  Temperature   Day sin   Day cos  Year sin  \
# Date Time
# 2009-01-01 01:00:00    996.50        -8.05  0.258819  0.965926  0.010049
# 2009-01-01 02:00:00    996.62        -8.88  0.500000  0.866025  0.010766
# 2009-01-01 03:00:00    996.84        -8.81  0.707107  0.707107  0.011483
# 2009-01-01 04:00:00    996.99        -9.05  0.866025  0.500000  0.012199
# 2009-01-01 05:00:00    997.46        -9.63  0.965926  0.258819  0.012916
#
#                      Year cos
# Date Time
# 2009-01-01 01:00:00  0.999950
# 2009-01-01 02:00:00  0.999942
# 2009-01-01 03:00:00  0.999934
# 2009-01-01 04:00:00  0.999926
# 2009-01-01 05:00:00  0.999917

# %%
def df_to_X_y3(df, window_size=7):
  df_as_np = df.to_numpy()
  X = []
  y = []
  for i in range(len(df_as_np)-window_size):
    row = [r for r in df_as_np[i:i+window_size]]
    X.append(row)
    label = [df_as_np[i+window_size][0], df_as_np[i+window_size][1]]
    y.append(label)
  return np.array(X), np.array(y)

# %%
X3, y3 = df_to_X_y3(p_temp_df)
X3.shape, y3.shape
# Out:
# ((70084, 7, 6), (70084, 2))

# %%
X3_train, y3_train = X3[:60000], y3[:60000]
X3_val, y3_val = X3[60000:65000], y3[60000:65000]
X3_test, y3_test = X3[65000:], y3[65000:]
X3_train.shape, y3_train.shape, X3_val.shape, y3_val.shape, X3_test.shape, y3_test.shape
# Out:
# ((60000, 7, 6), (60000, 2), (5000, 7, 6), (5000, 2), (5084, 7, 6), (5084, 2))

# %%
p_training_mean3 = np.mean(X3_train[:, :, 0])
p_training_std3 = np.std(X3_train[:, :, 0])

temp_training_mean3 = np.mean(X3_train[:, :, 1])
temp_training_std3 = np.std(X3_train[:, :, 1])

def preprocess3(X):
  X[:, :, 0] = (X[:, :, 0] - p_training_mean3) / p_training_std3
  X[:, :, 1] = (X[:, :, 1] - temp_training_mean3) / temp_training_std3

def preprocess_output3(y):
  y[:, 0] = (y[:, 0] - p_training_mean3) / p_training_std3
  y[:, 1] = (y[:, 1] - temp_training_mean3) / temp_training_std3
  return y

# %%
preprocess3(X3_train)
preprocess3(X3_val)
preprocess3(X3_test)

# %%
preprocess_output3(y3_train)
preprocess_output3(y3_val)
preprocess_output3(y3_test)
# Out:
# array([[-0.7934386 ,  0.41245076],
#        [-0.76312281,  0.35368268],
#        [-0.72189335,  0.32312327],
#        ...,
#        [ 1.48145784, -1.43051636],
#        [ 1.41597574, -1.44697142],
#        [ 1.35049365, -1.56920903]])

# %%
model5 = Sequential()
model5.add(InputLayer((7, 6)))
model5.add(LSTM(64))
model5.add(Dense(8, 'relu'))
model5.add(Dense(2, 'linear'))

model5.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                        │ (None, 64)                  │          18,176 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 2)                   │              18 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 18,714 (73.10 KB)
#  Trainable params: 18,714 (73.10 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp5 = ModelCheckpoint('model5.keras', save_best_only=True)
model5.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model5.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=10, callbacks=[cp5])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.2935 - root_mean_squared_error: 0.5158 - val_loss: 0.0307 - val_root_mean_squared_error: 0.1752
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0286 - root_mean_squared_error: 0.1685 - val_loss: 0.0169 - val_root_mean_squared_error: 0.1298
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - loss: 0.0140 - root_mean_squared_error: 0.1181 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0878
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - loss: 0.0080 - root_mean_squared_error: 0.0895 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0757
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.0060 - root_mean_squared_error: 0.0775 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0672
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0059 - root_mean_squared_error: 0.0766 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0639
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0701 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0633
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - loss: 0.0045 - root_mean_squared_error: 0.0674 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0628
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0622
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0679 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0612

# %%
def plot_predictions2(model, X, y, start=0, end=100):
  predictions = model.predict(X)
  p_preds, temp_preds = predictions[:, 0], predictions[:, 1]
  p_actuals, temp_actuals = y[:, 0], y[:, 1]
  df = pd.DataFrame(data={'Temperature Predictions': temp_preds,
                          'Temperature Actuals':temp_actuals,
                          'Pressure Predictions': p_preds,
                          'Pressure Actuals': p_actuals
                          })
  plt.plot(df['Temperature Predictions'][start:end])
  plt.plot(df['Temperature Actuals'][start:end])
  plt.plot(df['Pressure Predictions'][start:end])
  plt.plot(df['Pressure Actuals'][start:end])
  return df[start:end]

# %%
plot_predictions2(model5, X3_test, y3_test)
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#     Temperature Predictions  Temperature Actuals  Pressure Predictions  \
# 0                  0.405835             0.412451             -0.790580
# 1                  0.359770             0.353683             -0.781121
# 2                  0.317893             0.323123             -0.750062
# 3                  0.319178             0.250251             -0.695429
# 4                  0.271070             0.254952             -0.607762
# ..                      ...                  ...                   ...
# 95                 0.688466             0.716869             -0.411912
# 96                 0.649909             0.687485             -0.417471
# 97                 0.632538             0.663978             -0.405373
# 98                 0.633962             0.641646             -0.395478
# 99                 0.646346             0.653400             -0.383596
#
#     Pressure Actuals
# 0          -0.793439
# 1          -0.763123
# 2          -0.721893
# 3          -0.652773
# 4          -0.652773
# ..               ...
# 95         -0.416310
# 96         -0.399333
# 97         -0.399333
# 98         -0.400546
# 99         -0.369018
#
# [100 rows x 4 columns]

# %%
def postprocess_temp(arr):
  arr = (arr*temp_training_std3) + temp_training_mean3
  return arr

def postprocess_p(arr):
  arr = (arr*p_training_std3) + p_training_mean3
  return arr

# %%
def plot_predictions2(model, X, y, start=0, end=100):
  predictions = model.predict(X)
  p_preds, temp_preds = postprocess_p(predictions[:, 0]), postprocess_temp(predictions[:, 1])
  p_actuals, temp_actuals = postprocess_p(y[:, 0]), postprocess_temp(y[:, 1])
  df = pd.DataFrame(data={'Temperature Predictions': temp_preds,
                          'Temperature Actuals':temp_actuals,
                          'Pressure Predictions': p_preds,
                          'Pressure Actuals': p_actuals
                          })
  plt.plot(df['Temperature Predictions'][start:end])
  plt.plot(df['Temperature Actuals'][start:end])
  plt.plot(df['Pressure Predictions'][start:end])
  plt.plot(df['Pressure Actuals'][start:end])
  return df[start:end]

# %%
post_processed_df = plot_predictions2(model5, X3_test, y3_test)
post_processed_df
# Out:
# 159/159 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#     Temperature Predictions  Temperature Actuals  Pressure Predictions  \
# 0                 12.873711                12.93            982.453613
# 1                 12.481792                12.43            982.531616
# 2                 12.125498                12.17            982.787720
# 3                 12.136438                11.55            983.238281
# 4                 11.727127                11.59            983.961243
# ..                      ...                  ...                   ...
# 95                15.278347                15.52            985.576294
# 96                14.950304                15.27            985.530457
# 97                14.802509                15.07            985.630249
# 98                14.814626                14.88            985.711792
# 99                14.919982                14.98            985.809814
#
#     Pressure Actuals
# 0             982.43
# 1             982.68
# 2             983.02
# 3             983.59
# 4             983.59
# ..               ...
# 95            985.54
# 96            985.68
# 97            985.68
# 98            985.67
# 99            985.93
#
# [100 rows x 4 columns]

# %%
start, end = 0, 100
plt.plot(post_processed_df['Temperature Predictions'][start:end])
plt.plot(post_processed_df['Temperature Actuals'][start:end])

# %%
plt.plot(post_processed_df['Pressure Predictions'][start:end])
plt.plot(post_processed_df['Pressure Actuals'][start:end])

# %%
model6 = Sequential()
model6.add(InputLayer((7, 6)))
model6.add(LSTM(32, return_sequences=True))
model6.add(LSTM(64))
model6.add(Dense(8, 'relu'))
model6.add(Dense(2, 'linear'))

model6.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_3 (LSTM)                        │ (None, 7, 32)               │           4,992 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_4 (LSTM)                        │ (None, 64)                  │          24,832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 8)                   │             520 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 2)                   │              18 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 30,362 (118.60 KB)
#  Trainable params: 30,362 (118.60 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
cp6 = ModelCheckpoint('model6.keras', save_best_only=True)
model6.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])

# %%
model6.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=10, callbacks=[cp6])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 17s 7ms/step - loss: 0.4883 - root_mean_squared_error: 0.6861 - val_loss: 0.1418 - val_root_mean_squared_error: 0.3765
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - loss: 0.0994 - root_mean_squared_error: 0.3130 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1529
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0205 - root_mean_squared_error: 0.1430 - val_loss: 0.0125 - val_root_mean_squared_error: 0.1118
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - loss: 0.0123 - root_mean_squared_error: 0.1109 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0090 - root_mean_squared_error: 0.0950 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0851
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - loss: 0.0071 - root_mean_squared_error: 0.0845 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0743
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0061 - root_mean_squared_error: 0.0779 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0754
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - loss: 0.0058 - root_mean_squared_error: 0.0762 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0666
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 21s 7ms/step - loss: 0.0059 - root_mean_squared_error: 0.0764 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0659
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 20s 7ms/step - loss: 0.0060 - root_mean_squared_error: 0.0773 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0644

# %%
model7 = Sequential()
model7.add(InputLayer((7, 6)))
model7.add(Conv1D(64, kernel_size=2, activation='relu'))
model7.add(Flatten())
model7.add(Dense(8, 'relu'))
model7.add(Dense(2, 'linear'))
model7.summary()

cp7 = ModelCheckpoint('model6.keras', save_best_only=True)
model7.compile(loss=MeanSquaredError(), optimizer=Adam(learning_rate=0.0001), metrics=[RootMeanSquaredError()])
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv1d_1 (Conv1D)                    │ (None, 6, 64)               │             832 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 384)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 8)                   │           3,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 2)                   │              18 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 3,930 (15.35 KB)
#  Trainable params: 3,930 (15.35 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model7.fit(X3_train, y3_train, validation_data=(X3_val, y3_val), epochs=10, callbacks=[cp7])
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.1903 - root_mean_squared_error: 0.4084 - val_loss: 0.0176 - val_root_mean_squared_error: 0.1327
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0143 - root_mean_squared_error: 0.1197 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0927
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0091 - root_mean_squared_error: 0.0952 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0816
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0070 - root_mean_squared_error: 0.0839 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0762
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - loss: 0.0081 - root_mean_squared_error: 0.0887 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0724
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0060 - root_mean_squared_error: 0.0776 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0705
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0054 - root_mean_squared_error: 0.0731 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0679
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - loss: 0.0055 - root_mean_squared_error: 0.0742 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0666
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0050 - root_mean_squared_error: 0.0709 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0656
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - loss: 0.0050 - root_mean_squared_error: 0.0704 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0661
